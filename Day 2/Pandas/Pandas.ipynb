# %% [markdown]
# ## Library

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd

# %% [markdown]
# ## Creating Dataframes

# %%
fruits1_dict = {'Fruit' : ['Apple', 'Banana', 'Orange'],
                'Color' : ['Red', 'Yellow', 'Orange']}

fruits1 = pd.DataFrame(fruits1_dict)
fruits1
# Out:
#     Fruit   Color
# 0   Apple     Red
# 1  Banana  Yellow
# 2  Orange  Orange

# %%
fruits2_list = [['Kiwi', 'Green'], ['Lemon', 'Yellow'], ['Plums', 'Dark Red']]
fruits2 = pd.DataFrame(fruits2_list, columns = ['Fruit', 'Color'])
fruits2
# Out:
#    Fruit     Color
# 0   Kiwi     Green
# 1  Lemon    Yellow
# 2  Plums  Dark Red

# %%
fruits = pd.concat([fruits1, fruits2])
fruits
# Out:
#     Fruit     Color
# 0   Apple       Red
# 1  Banana    Yellow
# 2  Orange    Orange
# 0    Kiwi     Green
# 1   Lemon    Yellow
# 2   Plums  Dark Red

# %% [markdown]
# ## Data loading and Inspection

# %%
# To read a CSV file
data = pd.read_csv("iris_csv.csv")

# to read a TSV file
# pd.read_tsv("dataset_path")

# to read a TSV file using CSV
# pd.read_csv("dataset_path", sep = '\t')

# %% [markdown]
# Basic Data Observations

# %%
data.head()
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
data.head(3)
# Out:
#    sepallength  sepalwidth  petallength  petalwidth        class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa

# %%
data.tail()
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica

# %% [markdown]
# **Data Inspection**

# %%
data.shape
# Out:
# (150, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepallength  150 non-null    float64
#  1   sepalwidth   150 non-null    float64
#  2   petallength  150 non-null    float64
#  3   petalwidth   150 non-null    float64
#  4   class        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.describe()
# Out:
#        sepallength  sepalwidth  petallength  petalwidth
# count   150.000000  150.000000   150.000000  150.000000
# mean      5.843333    3.054000     3.758667    1.198667
# std       0.828066    0.433594     1.764420    0.763161
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.350000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %% [markdown]
# **Accessing Columns Data**

# %%
data.sepallength
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepallength, Length: 150, dtype: float64

# %%
data.nunique()
# Out:
# sepallength    35
# sepalwidth     23
# petallength    43
# petalwidth     22
# class           3
# dtype: int64

# %%
data['sepalwidth'].value_counts().head()
# Out:
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# Name: sepalwidth, dtype: int64

# %% [markdown]
# ## Data Selection and Indexing

# %% [markdown]
# Selecting Columns and Rows

# %%
data[['sepalwidth', 'sepallength']]
# Out:
#      sepalwidth  sepallength
# 0           3.5          5.1
# 1           3.0          4.9
# 2           3.2          4.7
# 3           3.1          4.6
# 4           3.6          5.0
# ..          ...          ...
# 145         3.0          6.7
# 146         2.5          6.3
# 147         3.0          6.5
# 148         3.4          6.2
# 149         3.0          5.9
#
# [150 rows x 2 columns]

# %% [markdown]
# Using **'.loc[]'**

# %%
data.loc[15:25, 'sepallength':'petallength']
# Out:
#     sepallength  sepalwidth  petallength
# 15          5.7         4.4          1.5
# 16          5.4         3.9          1.3
# 17          5.1         3.5          1.4
# 18          5.7         3.8          1.7
# 19          5.1         3.8          1.5
# 20          5.4         3.4          1.7
# 21          5.1         3.7          1.5
# 22          4.6         3.6          1.0
# 23          5.1         3.3          1.7
# 24          4.8         3.4          1.9
# 25          5.0         3.0          1.6

# %%
data.loc[75,:]
# Out:
# sepallength                6.6
# sepalwidth                 3.0
# petallength                4.4
# petalwidth                 1.4
# class          Iris-versicolor
# Name: 75, dtype: object

# %%
data.loc[:,'petalwidth']
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: petalwidth, Length: 150, dtype: float64

# %% [markdown]
# Using **'.iloc[]'**

# %%
data.iloc[9,2] # value of 9th row, 2nd column
# Out:
# 1.5

# %%
data.iloc[5:10, 1:3] # rows from 5 to 9 from 1st and 2nd column
# Out:
#    sepalwidth  petallength
# 5         3.9          1.7
# 6         3.4          1.4
# 7         3.4          1.5
# 8         2.9          1.4
# 9         3.1          1.5

# %%
data.iloc[[7, 9, 11], 0:2] #only 7,9 and 11th rows data
# Out:
#     sepallength  sepalwidth
# 7           5.0         3.4
# 9           4.9         3.1
# 11          4.8         3.4

# %%
data.corr()
# Out:
# <ipython-input-60-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#              sepallength  sepalwidth  petallength  petalwidth
# sepallength     1.000000   -0.109369     0.871754    0.817954
# sepalwidth     -0.109369    1.000000    -0.420516   -0.356544
# petallength     0.871754   -0.420516     1.000000    0.962757
# petalwidth      0.817954   -0.356544     0.962757    1.000000

# %%
data.groupby(data['sepalwidth']).agg(['mean', 'min','max'])
# Out:
# <ipython-input-65-19b246205d4e>:1: FutureWarning: ['class'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   data.groupby(data['sepalwidth']).agg(['mean', 'min','max'])
#            sepallength           petallength           petalwidth
#                   mean  min  max        mean  min  max       mean  min  max
# sepalwidth
# 2.0           5.000000  5.0  5.0    3.500000  3.5  3.5   1.000000  1.0  1.0
# 2.2           6.066667  6.0  6.2    4.500000  4.0  5.0   1.333333  1.0  1.5
# 2.3           5.325000  4.5  6.3    3.250000  1.3  4.4   0.975000  0.3  1.3
# 2.4           5.300000  4.9  5.5    3.600000  3.3  3.8   1.033333  1.0  1.1
# 2.5           5.762500  4.9  6.7    4.512500  3.0  5.8   1.550000  1.1  2.0
# 2.6           6.160000  5.5  7.7    4.880000  3.5  6.9   1.420000  1.0  2.3
# 2.7           5.855556  5.2  6.4    4.622222  3.9  5.3   1.555556  1.0  1.9
# 2.8           6.335714  5.6  7.7    5.042857  4.0  6.7   1.707143  1.2  2.4
# 2.9           6.060000  4.4  7.3    4.350000  1.4  6.3   1.320000  0.2  1.8
# 3.0           6.015385  4.3  7.7    4.234615  1.1  6.6   1.403846  0.1  2.3
# 3.1           5.941667  4.6  6.9    3.600000  1.5  5.6   1.141667  0.1  2.4
# 3.2           5.884615  4.4  7.2    3.753846  1.2  6.0   1.261538  0.2  2.3
# 3.3           6.016667  5.0  6.7    4.200000  1.4  6.0   1.566667  0.2  2.5
# 3.4           5.316667  4.6  6.3    2.466667  1.4  5.6   0.716667  0.2  2.4
# 3.5           5.150000  5.0  5.5    1.416667  1.3  1.6   0.300000  0.2  0.6
# 3.6           5.600000  4.6  7.2    2.833333  1.0  6.1   0.966667  0.2  2.5
# 3.7           5.266667  5.1  5.4    1.500000  1.5  1.5   0.266667  0.2  0.4
# 3.8           6.100000  5.1  7.9    3.300000  1.5  6.7   0.900000  0.2  2.2
# 3.9           5.400000  5.4  5.4    1.500000  1.3  1.7   0.400000  0.4  0.4
# 4.0           5.800000  5.8  5.8    1.200000  1.2  1.2   0.200000  0.2  0.2
# 4.1           5.200000  5.2  5.2    1.500000  1.5  1.5   0.100000  0.1  0.1
# 4.2           5.500000  5.5  5.5    1.400000  1.4  1.4   0.200000  0.2  0.2
# 4.4           5.700000  5.7  5.7    1.500000  1.5  1.5   0.400000  0.4  0.4
